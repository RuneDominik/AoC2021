# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
points = np.genfromtxt(r'../data/day13_data/result_part_2.txt', delimiter=',')

# %%
plt.figure(figsize=(40, 6))
for point in points:
    plt.plot(point[0], point[1], 'kx', markersize=10)
plt.gca().invert_yaxis()
plt.show()
